# %%
import requests
from time import sleep
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid', font_scale=1.3, palette='Set2')

# %%
URL = 'https://api.hh.ru/vacancies'

params = {
    'text': "Data Scientist",
    'area': 1,
    'page': 0,
    'per_page': 10
}

req = requests.get(URL, params)
data = json.loads(req.content.decode())

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
#посмотрим описание первой вакансии
data['items'][0]
# Out:
# {'id': '79165756',
#  'premium': False,
#  'name': 'Data Scientist',
#  'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 300000, 'to': 400000, 'currency': 'RUR', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2023-04-11T15:05:03+0300',
#  'created_at': '2023-04-11T15:05:03+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=79165756',
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/79165756?host=hh.ru',
#  'adv_response_url': None,
#  'alternate_url': 'https://hh.ru/vacancy/79165756',
#  'relations': [],
#  'employer': {'id': '3529',
#   'name': 'СБЕР',
#   'url': 'https://api.hh.ru/employers/3529',
#   'alternate_url': 'https://hh.ru/employer/3529',
#   'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/5756157.png',
#    '90': 'https://hhcdn.ru/employer-logo/5756156.png',
#    'original': 'https://hhcdn.ru/employer-logo-original/1033849.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#   'trusted': True},
#  'snippet': {'requirement': 'Хорошие коммуникационные навыки, customer focus. Linux – на уровне пользователя. Python – знание языка, Numpy, Pandas, Matplotlib/Plotly. Знание одного из фреймворков...',
#   'responsibility': 'Технический enabling: осуществлять техническую поддержку продуктового HW/SW стека проекта внутри экосистемы банка ( + внешние пользователи при необходимости ). '},
#  'contacts': None,
#  'schedule': None,
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#  'accept_incomplete_resumes': False}

# %%
# сколько найдено вакансий
data['found']
# Out:
# 306

# %%
# страниц в результатах поиска
data['pages']
# Out:
# 31

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# С помощью метода pandas.json_normalize разберем структурированные данные из JSON в табличный формат.

# %%
df = pd.json_normalize(data['items'])
df.head()
# Out:
#          id  premium                                               name  \
# 0  79165756    False                                     Data Scientist
# 1  79110745    False                                      Data Engineer
# 2  78876532    False  Эконометрист/Data scientist (Junior/Middle) в ...
# 3  79112858    False                                 Data Scientist R&D
# 4  78706463    False                                     Data Scientist
#
#    has_test  response_letter_required  address response_url  \
# 0     False                     False      NaN         None
# 1     False                     False      NaN         None
# 2     False                     False      NaN         None
# 3     False                     False      NaN         None
# 4      True                     False      NaN         None
#
#   sort_point_distance              published_at                created_at  \
# 0                None  2023-04-11T15:05:03+0300  2023-04-11T15:05:03+0300
# 1                None  2023-04-10T14:42:13+0300  2023-04-10T14:42:13+0300
# 2                None  2023-04-10T10:13:48+0300  2023-04-10T10:13:48+0300
# 3                None  2023-04-10T15:12:05+0300  2023-04-10T15:12:05+0300
# 4                None  2023-04-12T09:26:59+0300  2023-04-12T09:26:59+0300
#
#    archived                                apply_alternate_url  \
# 0     False  https://hh.ru/applicant/vacancy_response?vacan...
# 1     False  https://hh.ru/applicant/vacancy_response?vacan...
# 2     False  https://hh.ru/applicant/vacancy_response?vacan...
# 3     False  https://hh.ru/applicant/vacancy_response?vacan...
# 4     False  https://hh.ru/applicant/vacancy_response?vacan...
#
#   insider_interview                                              url  \
# 0              None  https://api.hh.ru/vacancies/79165756?host=hh.ru
# 1              None  https://api.hh.ru/vacancies/79110745?host=hh.ru
# 2              None  https://api.hh.ru/vacancies/78876532?host=hh.ru
# 3              None  https://api.hh.ru/vacancies/79112858?host=hh.ru
# 4              None  https://api.hh.ru/vacancies/78706463?host=hh.ru
#
#   adv_response_url                   alternate_url relations contacts  \
# 0             None  https://hh.ru/vacancy/79165756        []     None
# 1             None  https://hh.ru/vacancy/79110745        []     None
# 2             None  https://hh.ru/vacancy/78876532        []     None
# 3             None  https://hh.ru/vacancy/79112858        []     None
# 4             None  https://hh.ru/vacancy/78706463        []     None
#
#   schedule working_days working_time_intervals working_time_modes  \
# 0     None           []                     []                 []
# 1     None           []                     []                 []
# 2     None           []                     []                 []
# 3     None           []                     []                 []
# 4     None           []                     []                 []
#
#    accept_temporary                                 professional_roles  \
# 0             False          [{'id': '165', 'name': 'Дата-сайентист'}]
# 1              True  [{'id': '96', 'name': 'Программист, разработчи...
# 2              True                 [{'id': '10', 'name': 'Аналитик'}]
# 3             False          [{'id': '165', 'name': 'Дата-сайентист'}]
# 4             False          [{'id': '165', 'name': 'Дата-сайентист'}]
#
#    accept_incomplete_resumes department.id department.name area.id area.name  \
# 0                      False  3529-3529-it        Сбер. IT       1    Москва
# 1                      False           NaN             NaN       1    Москва
# 2                      False           NaN             NaN       1    Москва
# 3                      False           NaN             NaN       1    Москва
# 4                      False           NaN             NaN       1    Москва
#
#                     area.url  salary.from  salary.to salary.currency  \
# 0  https://api.hh.ru/areas/1     300000.0   400000.0             RUR
# 1  https://api.hh.ru/areas/1       4000.0     6000.0             EUR
# 2  https://api.hh.ru/areas/1      40000.0        NaN             RUR
# 3  https://api.hh.ru/areas/1     150000.0   300000.0             RUR
# 4  https://api.hh.ru/areas/1          NaN   300000.0             RUR
#
#   salary.gross type.id type.name employer.id              employer.name  \
# 0        False    open  Открытая        3529                       СБЕР
# 1         True    open  Открытая     5231648   4CV Recruitment Services
# 2        False    open  Открытая     2724615  БСТ Менеджмент-Консалтинг
# 3         True    open  Открытая     2223982                    Rubbles
# 4        False    open  Открытая     2324020                      Точка
#
#                           employer.url          employer.alternate_url  \
# 0     https://api.hh.ru/employers/3529     https://hh.ru/employer/3529
# 1  https://api.hh.ru/employers/5231648  https://hh.ru/employer/5231648
# 2  https://api.hh.ru/employers/2724615  https://hh.ru/employer/2724615
# 3  https://api.hh.ru/employers/2223982  https://hh.ru/employer/2223982
# 4  https://api.hh.ru/employers/2324020  https://hh.ru/employer/2324020
#
#                         employer.logo_urls.240  \
# 0   https://hhcdn.ru/employer-logo/5756157.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030643.jpeg
# 3   https://hhcdn.ru/employer-logo/3987732.png
# 4  https://hhcdn.ru/employer-logo/3414734.jpeg
#
#                          employer.logo_urls.90  \
# 0   https://hhcdn.ru/employer-logo/5756156.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030642.jpeg
# 3   https://hhcdn.ru/employer-logo/3987731.png
# 4  https://hhcdn.ru/employer-logo/3414733.jpeg
#
#                          employer.logo_urls.original  \
# 0  https://hhcdn.ru/employer-logo-original/103384...
# 1                                                NaN
# 2  https://hhcdn.ru/employer-logo-original/397097...
# 3  https://hhcdn.ru/employer-logo-original/886758...
# 4  https://hhcdn.ru/employer-logo-original/743443...
#
#                             employer.vacancies_url  employer.trusted  \
# 0     https://api.hh.ru/vacancies?employer_id=3529              True
# 1  https://api.hh.ru/vacancies?employer_id=5231648              True
# 2  https://api.hh.ru/vacancies?employer_id=2724615              True
# 3  https://api.hh.ru/vacancies?employer_id=2223982              True
# 4  https://api.hh.ru/vacancies?employer_id=2324020              True
#
#                                  snippet.requirement  \
# 0  Хорошие коммуникационные навыки, customer focu...
# 1  Разговорный английский. Опыт работы <highlight...
# 2  Экономическое или техническое образование. (пр...
# 3  Опыт работы с классическими ML-алгоритмами (Бу...
# 4  Есть опыт работы с методами машинного обучения...
#
#                               snippet.responsibility  department  \
# 0  Технический enabling: осуществлять техническую...         NaN
# 1  Взаимодействие с <highlighttext>data</highligh...         NaN
# 2  Построение моделей эластичности спроса на банк...         NaN
# 3  Проверка и валидация бизнес-гипотез с существе...         NaN
# 4  Команды работают с последними технологиями, об...         NaN
#
#    employer.logo_urls address.city        address.street  address.building  \
# 0                 NaN          NaN                   NaN               NaN
# 1                 NaN          NaN                   NaN               NaN
# 2                 NaN       Москва  Замоскворецкая линия  метро Маяковская
# 3                 NaN       Москва         проспект Мира               3с3
# 4                 NaN          NaN                   NaN               NaN
#
#    address.lat  address.lng  address.description  \
# 0          NaN          NaN                  NaN
# 1          NaN          NaN                  NaN
# 2    55.769808    37.596192                  NaN
# 3    55.773444    37.631640                  NaN
# 4          NaN          NaN                  NaN
#
#                                       address.raw  address.metro  \
# 0                                             NaN            NaN
# 1                                             NaN            NaN
# 2  Москва, Замоскворецкая линия, метро Маяковская            NaN
# 3                      Москва, проспект Мира, 3с3            NaN
# 4                                             NaN            NaN
#
#   address.metro_stations address.id address.metro.station_name  \
# 0                    NaN        NaN                        NaN
# 1                    NaN        NaN                        NaN
# 2                     []    1000883                        NaN
# 3                     []    2234484                        NaN
# 4                    NaN        NaN                        NaN
#
#   address.metro.line_name address.metro.station_id address.metro.line_id  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                     NaN                      NaN                   NaN
# 3                     NaN                      NaN                   NaN
# 4                     NaN                      NaN                   NaN
#
#    address.metro.lat  address.metro.lng  salary
# 0                NaN                NaN     NaN
# 1                NaN                NaN     NaN
# 2                NaN                NaN     NaN
# 3                NaN                NaN     NaN
# 4                NaN                NaN     NaN

# %%
df.shape
# Out:
# (10, 66)

# %% [markdown]
# Видимо, что в столбце 'professional_roles' данные не нормализовались. Что бы разобрать вложенный список из professional_roles для начала избавимся от пропусков

# %%
df[['professional_roles_id', 'professional_roles_name']] = df['professional_roles'].apply(lambda x: pd.Series([x[0]['id'], x[0]['name']]))

# %%
df.head()
# Out:
#          id  premium                                               name  \
# 0  79165756    False                                     Data Scientist
# 1  79110745    False                                      Data Engineer
# 2  78876532    False  Эконометрист/Data scientist (Junior/Middle) в ...
# 3  79112858    False                                 Data Scientist R&D
# 4  78706463    False                                     Data Scientist
#
#    has_test  response_letter_required  address response_url  \
# 0     False                     False      NaN         None
# 1     False                     False      NaN         None
# 2     False                     False      NaN         None
# 3     False                     False      NaN         None
# 4      True                     False      NaN         None
#
#   sort_point_distance              published_at                created_at  \
# 0                None  2023-04-11T15:05:03+0300  2023-04-11T15:05:03+0300
# 1                None  2023-04-10T14:42:13+0300  2023-04-10T14:42:13+0300
# 2                None  2023-04-10T10:13:48+0300  2023-04-10T10:13:48+0300
# 3                None  2023-04-10T15:12:05+0300  2023-04-10T15:12:05+0300
# 4                None  2023-04-12T09:26:59+0300  2023-04-12T09:26:59+0300
#
#    archived                                apply_alternate_url  \
# 0     False  https://hh.ru/applicant/vacancy_response?vacan...
# 1     False  https://hh.ru/applicant/vacancy_response?vacan...
# 2     False  https://hh.ru/applicant/vacancy_response?vacan...
# 3     False  https://hh.ru/applicant/vacancy_response?vacan...
# 4     False  https://hh.ru/applicant/vacancy_response?vacan...
#
#   insider_interview                                              url  \
# 0              None  https://api.hh.ru/vacancies/79165756?host=hh.ru
# 1              None  https://api.hh.ru/vacancies/79110745?host=hh.ru
# 2              None  https://api.hh.ru/vacancies/78876532?host=hh.ru
# 3              None  https://api.hh.ru/vacancies/79112858?host=hh.ru
# 4              None  https://api.hh.ru/vacancies/78706463?host=hh.ru
#
#   adv_response_url                   alternate_url relations contacts  \
# 0             None  https://hh.ru/vacancy/79165756        []     None
# 1             None  https://hh.ru/vacancy/79110745        []     None
# 2             None  https://hh.ru/vacancy/78876532        []     None
# 3             None  https://hh.ru/vacancy/79112858        []     None
# 4             None  https://hh.ru/vacancy/78706463        []     None
#
#   schedule working_days working_time_intervals working_time_modes  \
# 0     None           []                     []                 []
# 1     None           []                     []                 []
# 2     None           []                     []                 []
# 3     None           []                     []                 []
# 4     None           []                     []                 []
#
#    accept_temporary                                 professional_roles  \
# 0             False          [{'id': '165', 'name': 'Дата-сайентист'}]
# 1              True  [{'id': '96', 'name': 'Программист, разработчи...
# 2              True                 [{'id': '10', 'name': 'Аналитик'}]
# 3             False          [{'id': '165', 'name': 'Дата-сайентист'}]
# 4             False          [{'id': '165', 'name': 'Дата-сайентист'}]
#
#    accept_incomplete_resumes department.id department.name area.id area.name  \
# 0                      False  3529-3529-it        Сбер. IT       1    Москва
# 1                      False           NaN             NaN       1    Москва
# 2                      False           NaN             NaN       1    Москва
# 3                      False           NaN             NaN       1    Москва
# 4                      False           NaN             NaN       1    Москва
#
#                     area.url  salary.from  salary.to salary.currency  \
# 0  https://api.hh.ru/areas/1     300000.0   400000.0             RUR
# 1  https://api.hh.ru/areas/1       4000.0     6000.0             EUR
# 2  https://api.hh.ru/areas/1      40000.0        NaN             RUR
# 3  https://api.hh.ru/areas/1     150000.0   300000.0             RUR
# 4  https://api.hh.ru/areas/1          NaN   300000.0             RUR
#
#   salary.gross type.id type.name employer.id              employer.name  \
# 0        False    open  Открытая        3529                       СБЕР
# 1         True    open  Открытая     5231648   4CV Recruitment Services
# 2        False    open  Открытая     2724615  БСТ Менеджмент-Консалтинг
# 3         True    open  Открытая     2223982                    Rubbles
# 4        False    open  Открытая     2324020                      Точка
#
#                           employer.url          employer.alternate_url  \
# 0     https://api.hh.ru/employers/3529     https://hh.ru/employer/3529
# 1  https://api.hh.ru/employers/5231648  https://hh.ru/employer/5231648
# 2  https://api.hh.ru/employers/2724615  https://hh.ru/employer/2724615
# 3  https://api.hh.ru/employers/2223982  https://hh.ru/employer/2223982
# 4  https://api.hh.ru/employers/2324020  https://hh.ru/employer/2324020
#
#                         employer.logo_urls.240  \
# 0   https://hhcdn.ru/employer-logo/5756157.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030643.jpeg
# 3   https://hhcdn.ru/employer-logo/3987732.png
# 4  https://hhcdn.ru/employer-logo/3414734.jpeg
#
#                          employer.logo_urls.90  \
# 0   https://hhcdn.ru/employer-logo/5756156.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030642.jpeg
# 3   https://hhcdn.ru/employer-logo/3987731.png
# 4  https://hhcdn.ru/employer-logo/3414733.jpeg
#
#                          employer.logo_urls.original  \
# 0  https://hhcdn.ru/employer-logo-original/103384...
# 1                                                NaN
# 2  https://hhcdn.ru/employer-logo-original/397097...
# 3  https://hhcdn.ru/employer-logo-original/886758...
# 4  https://hhcdn.ru/employer-logo-original/743443...
#
#                             employer.vacancies_url  employer.trusted  \
# 0     https://api.hh.ru/vacancies?employer_id=3529              True
# 1  https://api.hh.ru/vacancies?employer_id=5231648              True
# 2  https://api.hh.ru/vacancies?employer_id=2724615              True
# 3  https://api.hh.ru/vacancies?employer_id=2223982              True
# 4  https://api.hh.ru/vacancies?employer_id=2324020              True
#
#                                  snippet.requirement  \
# 0  Хорошие коммуникационные навыки, customer focu...
# 1  Разговорный английский. Опыт работы <highlight...
# 2  Экономическое или техническое образование. (пр...
# 3  Опыт работы с классическими ML-алгоритмами (Бу...
# 4  Есть опыт работы с методами машинного обучения...
#
#                               snippet.responsibility  department  \
# 0  Технический enabling: осуществлять техническую...         NaN
# 1  Взаимодействие с <highlighttext>data</highligh...         NaN
# 2  Построение моделей эластичности спроса на банк...         NaN
# 3  Проверка и валидация бизнес-гипотез с существе...         NaN
# 4  Команды работают с последними технологиями, об...         NaN
#
#    employer.logo_urls address.city        address.street  address.building  \
# 0                 NaN          NaN                   NaN               NaN
# 1                 NaN          NaN                   NaN               NaN
# 2                 NaN       Москва  Замоскворецкая линия  метро Маяковская
# 3                 NaN       Москва         проспект Мира               3с3
# 4                 NaN          NaN                   NaN               NaN
#
#    address.lat  address.lng  address.description  \
# 0          NaN          NaN                  NaN
# 1          NaN          NaN                  NaN
# 2    55.769808    37.596192                  NaN
# 3    55.773444    37.631640                  NaN
# 4          NaN          NaN                  NaN
#
#                                       address.raw  address.metro  \
# 0                                             NaN            NaN
# 1                                             NaN            NaN
# 2  Москва, Замоскворецкая линия, метро Маяковская            NaN
# 3                      Москва, проспект Мира, 3с3            NaN
# 4                                             NaN            NaN
#
#   address.metro_stations address.id address.metro.station_name  \
# 0                    NaN        NaN                        NaN
# 1                    NaN        NaN                        NaN
# 2                     []    1000883                        NaN
# 3                     []    2234484                        NaN
# 4                    NaN        NaN                        NaN
#
#   address.metro.line_name address.metro.station_id address.metro.line_id  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                     NaN                      NaN                   NaN
# 3                     NaN                      NaN                   NaN
# 4                     NaN                      NaN                   NaN
#
#    address.metro.lat  address.metro.lng  salary professional_roles_id  \
# 0                NaN                NaN     NaN                   165
# 1                NaN                NaN     NaN                    96
# 2                NaN                NaN     NaN                    10
# 3                NaN                NaN     NaN                   165
# 4                NaN                NaN     NaN                   165
#
#     professional_roles_name
# 0            Дата-сайентист
# 1  Программист, разработчик
# 2                  Аналитик
# 3            Дата-сайентист
# 4            Дата-сайентист

# %%
# Выведем названия столбцов
print(df.columns)
# Out:
# Index(['id', 'premium', 'name', 'has_test', 'response_letter_required',
#        'address', 'response_url', 'sort_point_distance', 'published_at',
#        'created_at', 'archived', 'apply_alternate_url', 'insider_interview',
#        'url', 'adv_response_url', 'alternate_url', 'relations', 'contacts',
#        'schedule', 'working_days', 'working_time_intervals',
#        'working_time_modes', 'accept_temporary', 'professional_roles_id',
#        'professional_roles_name', 'accept_incomplete_resumes', 'department.id',
#        'department.name', 'area.id', 'area.name', 'area.url', 'salary.from',
#        'salary.to', 'salary.currency', 'salary.gross', 'type.id', 'type.name',
#        'employer.id', 'employer.name', 'employer.url',
#        'employer.alternate_url', 'employer.logo_urls.240',
#        'employer.logo_urls.90', 'employer.logo_urls.original',
#        'employer.vacancies_url', 'employer.trusted', 'snippet.requirement',
#        'snippet.responsibility', 'department', 'employer.logo_urls',
#        'address.city', 'address.street', 'address.building', 'address.lat',
#        'address.lng', 'address.description', 'address.raw', 'address.metro',
#        'address.metro_stations', 'address.id', 'salary',
#        'address.metro.station_name', 'address.metro.line_name',
#        'address.metro.station_id', 'address.metro.line_id',
#        'address.metro.lat', 'address.metro.lng'],
#       dtype='object')

# %%
# Предвинем два получившихся столбца на место изначального professional_roles, 
# а его не будем включать в обновленный датафрейм 
df=df[['id', 'premium', 'name', 'has_test', 'response_letter_required',
       'address', 'response_url', 'sort_point_distance', 'published_at',
       'created_at', 'archived', 'apply_alternate_url', 'insider_interview',
       'url', 'adv_response_url', 'alternate_url', 'relations', 'contacts',
       'schedule', 'working_days', 'working_time_intervals',
       'working_time_modes', 'accept_temporary', 'professional_roles_id',
       'professional_roles_name', 'accept_incomplete_resumes',
       'department.id', 'department.name', 'area.id', 'area.name', 'area.url',
       'salary.from', 'salary.to', 'salary.currency', 'salary.gross',
       'type.id', 'type.name', 'employer.id', 'employer.name', 'employer.url',
       'employer.alternate_url', 'employer.logo_urls.240',
       'employer.logo_urls.90', 'employer.logo_urls.original',
       'employer.vacancies_url', 'employer.trusted', 'snippet.requirement',
       'snippet.responsibility', 'department', 'employer.logo_urls',
       'address.city', 'address.street', 'address.building', 'address.lat',
       'address.lng', 'address.description', 'address.raw', 'address.metro',
       'address.metro_stations', 'address.id', 'salary',
       'address.metro.station_name', 'address.metro.line_name',
       'address.metro.station_id', 'address.metro.line_id',
       'address.metro.lat', 'address.metro.lng']]

# %%
df.head()
# Out:
#          id  premium                                               name  \
# 0  79165756    False                                     Data Scientist
# 1  79110745    False                                      Data Engineer
# 2  78876532    False  Эконометрист/Data scientist (Junior/Middle) в ...
# 3  79112858    False                                 Data Scientist R&D
# 4  78706463    False                                     Data Scientist
#
#    has_test  response_letter_required  address response_url  \
# 0     False                     False      NaN         None
# 1     False                     False      NaN         None
# 2     False                     False      NaN         None
# 3     False                     False      NaN         None
# 4      True                     False      NaN         None
#
#   sort_point_distance              published_at                created_at  \
# 0                None  2023-04-11T15:05:03+0300  2023-04-11T15:05:03+0300
# 1                None  2023-04-10T14:42:13+0300  2023-04-10T14:42:13+0300
# 2                None  2023-04-10T10:13:48+0300  2023-04-10T10:13:48+0300
# 3                None  2023-04-10T15:12:05+0300  2023-04-10T15:12:05+0300
# 4                None  2023-04-12T09:26:59+0300  2023-04-12T09:26:59+0300
#
#    archived                                apply_alternate_url  \
# 0     False  https://hh.ru/applicant/vacancy_response?vacan...
# 1     False  https://hh.ru/applicant/vacancy_response?vacan...
# 2     False  https://hh.ru/applicant/vacancy_response?vacan...
# 3     False  https://hh.ru/applicant/vacancy_response?vacan...
# 4     False  https://hh.ru/applicant/vacancy_response?vacan...
#
#   insider_interview                                              url  \
# 0              None  https://api.hh.ru/vacancies/79165756?host=hh.ru
# 1              None  https://api.hh.ru/vacancies/79110745?host=hh.ru
# 2              None  https://api.hh.ru/vacancies/78876532?host=hh.ru
# 3              None  https://api.hh.ru/vacancies/79112858?host=hh.ru
# 4              None  https://api.hh.ru/vacancies/78706463?host=hh.ru
#
#   adv_response_url                   alternate_url relations contacts  \
# 0             None  https://hh.ru/vacancy/79165756        []     None
# 1             None  https://hh.ru/vacancy/79110745        []     None
# 2             None  https://hh.ru/vacancy/78876532        []     None
# 3             None  https://hh.ru/vacancy/79112858        []     None
# 4             None  https://hh.ru/vacancy/78706463        []     None
#
#   schedule working_days working_time_intervals working_time_modes  \
# 0     None           []                     []                 []
# 1     None           []                     []                 []
# 2     None           []                     []                 []
# 3     None           []                     []                 []
# 4     None           []                     []                 []
#
#    accept_temporary professional_roles_id   professional_roles_name  \
# 0             False                   165            Дата-сайентист
# 1              True                    96  Программист, разработчик
# 2              True                    10                  Аналитик
# 3             False                   165            Дата-сайентист
# 4             False                   165            Дата-сайентист
#
#    accept_incomplete_resumes department.id department.name area.id area.name  \
# 0                      False  3529-3529-it        Сбер. IT       1    Москва
# 1                      False           NaN             NaN       1    Москва
# 2                      False           NaN             NaN       1    Москва
# 3                      False           NaN             NaN       1    Москва
# 4                      False           NaN             NaN       1    Москва
#
#                     area.url  salary.from  salary.to salary.currency  \
# 0  https://api.hh.ru/areas/1     300000.0   400000.0             RUR
# 1  https://api.hh.ru/areas/1       4000.0     6000.0             EUR
# 2  https://api.hh.ru/areas/1      40000.0        NaN             RUR
# 3  https://api.hh.ru/areas/1     150000.0   300000.0             RUR
# 4  https://api.hh.ru/areas/1          NaN   300000.0             RUR
#
#   salary.gross type.id type.name employer.id              employer.name  \
# 0        False    open  Открытая        3529                       СБЕР
# 1         True    open  Открытая     5231648   4CV Recruitment Services
# 2        False    open  Открытая     2724615  БСТ Менеджмент-Консалтинг
# 3         True    open  Открытая     2223982                    Rubbles
# 4        False    open  Открытая     2324020                      Точка
#
#                           employer.url          employer.alternate_url  \
# 0     https://api.hh.ru/employers/3529     https://hh.ru/employer/3529
# 1  https://api.hh.ru/employers/5231648  https://hh.ru/employer/5231648
# 2  https://api.hh.ru/employers/2724615  https://hh.ru/employer/2724615
# 3  https://api.hh.ru/employers/2223982  https://hh.ru/employer/2223982
# 4  https://api.hh.ru/employers/2324020  https://hh.ru/employer/2324020
#
#                         employer.logo_urls.240  \
# 0   https://hhcdn.ru/employer-logo/5756157.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030643.jpeg
# 3   https://hhcdn.ru/employer-logo/3987732.png
# 4  https://hhcdn.ru/employer-logo/3414734.jpeg
#
#                          employer.logo_urls.90  \
# 0   https://hhcdn.ru/employer-logo/5756156.png
# 1                                          NaN
# 2  https://hhcdn.ru/employer-logo/2030642.jpeg
# 3   https://hhcdn.ru/employer-logo/3987731.png
# 4  https://hhcdn.ru/employer-logo/3414733.jpeg
#
#                          employer.logo_urls.original  \
# 0  https://hhcdn.ru/employer-logo-original/103384...
# 1                                                NaN
# 2  https://hhcdn.ru/employer-logo-original/397097...
# 3  https://hhcdn.ru/employer-logo-original/886758...
# 4  https://hhcdn.ru/employer-logo-original/743443...
#
#                             employer.vacancies_url  employer.trusted  \
# 0     https://api.hh.ru/vacancies?employer_id=3529              True
# 1  https://api.hh.ru/vacancies?employer_id=5231648              True
# 2  https://api.hh.ru/vacancies?employer_id=2724615              True
# 3  https://api.hh.ru/vacancies?employer_id=2223982              True
# 4  https://api.hh.ru/vacancies?employer_id=2324020              True
#
#                                  snippet.requirement  \
# 0  Хорошие коммуникационные навыки, customer focu...
# 1  Разговорный английский. Опыт работы <highlight...
# 2  Экономическое или техническое образование. (пр...
# 3  Опыт работы с классическими ML-алгоритмами (Бу...
# 4  Есть опыт работы с методами машинного обучения...
#
#                               snippet.responsibility  department  \
# 0  Технический enabling: осуществлять техническую...         NaN
# 1  Взаимодействие с <highlighttext>data</highligh...         NaN
# 2  Построение моделей эластичности спроса на банк...         NaN
# 3  Проверка и валидация бизнес-гипотез с существе...         NaN
# 4  Команды работают с последними технологиями, об...         NaN
#
#    employer.logo_urls address.city        address.street  address.building  \
# 0                 NaN          NaN                   NaN               NaN
# 1                 NaN          NaN                   NaN               NaN
# 2                 NaN       Москва  Замоскворецкая линия  метро Маяковская
# 3                 NaN       Москва         проспект Мира               3с3
# 4                 NaN          NaN                   NaN               NaN
#
#    address.lat  address.lng  address.description  \
# 0          NaN          NaN                  NaN
# 1          NaN          NaN                  NaN
# 2    55.769808    37.596192                  NaN
# 3    55.773444    37.631640                  NaN
# 4          NaN          NaN                  NaN
#
#                                       address.raw  address.metro  \
# 0                                             NaN            NaN
# 1                                             NaN            NaN
# 2  Москва, Замоскворецкая линия, метро Маяковская            NaN
# 3                      Москва, проспект Мира, 3с3            NaN
# 4                                             NaN            NaN
#
#   address.metro_stations address.id  salary address.metro.station_name  \
# 0                    NaN        NaN     NaN                        NaN
# 1                    NaN        NaN     NaN                        NaN
# 2                     []    1000883     NaN                        NaN
# 3                     []    2234484     NaN                        NaN
# 4                    NaN        NaN     NaN                        NaN
#
#   address.metro.line_name address.metro.station_id address.metro.line_id  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                     NaN                      NaN                   NaN
# 3                     NaN                      NaN                   NaN
# 4                     NaN                      NaN                   NaN
#
#    address.metro.lat  address.metro.lng
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN

# %%
df['snippet.requirement'].iloc[1]
# Out:
# 'Разговорный английский. Опыт работы Data Engineer от 2х лет, предпочтительно с подготовкой датасетов для ML.'

# %% [markdown]
# Также видим, что в столбцах snippet.requirement	и snippet.responsibility есть теги. Если в тексте снипета встретилась поисковая фраза (параметр text ), она будет подсвечена тегом highlighttext (из документации по API). Но нам эти теги ни к чему, избавимся от них:

# %%
def remove_tags(text):
    if isinstance(text, str):
        return re.sub(r'<.*?>', '', text)
    else:
        return text

df[['snippet.requirement', 'snippet.responsibility']] = df[['snippet.requirement', 'snippet.responsibility']].applymap(remove_tags)

# %% [markdown]
# Для получения полного описания вакансии потребуется задать отдельный запрос, используя ее id.

# %%
df['snippet.requirement'].iloc[1]
# Out:
# 'Разговорный английский. Опыт работы <highlighttext>Data</highlighttext> Engineer от 2х лет, предпочтительно с подготовкой датасетов для ML.'

# %%
df['snippet.responsibility'].iloc[0]
# Out:
# 'Технический enabling: осуществлять техническую поддержку продуктового HW/SW стека проекта внутри экосистемы банка ( + внешние пользователи при необходимости ). '

# %%
vacancy = df['id'].iloc[0]
vacancy_url = f'https://api.hh.ru/vacancies/{vacancy}'

req = requests.get(vacancy_url)
vacancy_info = json.loads(req.content.decode())
vacancy_info
