# %%
import pandas as pd
df = pd.read_csv('data/data.csv')
df.head(10)
# Out:
#   Пол  Возраст            Город Готовность к переезду  \
# 0   Ж       25           Москва   не готов к переезду
# 1   М       33           Москва   не готов к переезду
# 2   Ж       19           Москва      готов к переезду
# 3   Ж       25           Тюмень   не готов к переезду
# 4   Ж       32           Москва   не готов к переезду
# 5   Ж        0           Москва   не готов к переезду
# 6   М       33      Новосибирск      готов к переезду
# 7   Ж       23           Якутск      готов к переезду
# 8   М       33  Санкт-Петербург      готов к переезду
# 9   Ж       39           Москва   не готов к переезду
#
#   Готовность к командировкам Гражданство Разрешение на работу  \
# 0      готов к командировкам      Россия               Россия
# 1      готов к командировкам      Россия               Россия
# 2      готов к командировкам    Беларусь               Россия
# 3      готов к командировкам      Россия               Россия
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Пол  Возраст            Город Готовность к переезду  \
# 0     Ж       25           Москва   не готов к переезду
# 1     М       33           Москва   не готов к переезду
# 2     Ж       19           Москва      готов к переезду
# 3     Ж       25           Тюмень   не готов к переезду
# 4     Ж       32           Москва   не готов к переезду
# ..   ..      ...              ...                   ...
# 559   Ж       33           Москва   не готов к переезду
# 560   Ж       39    Верхняя Пышма   не готов к переезду
# 561   Ж       27           Москва      готов к переезду
# 562   М       30  Санкт-Петербург      готов к переезду
# 563   Ж       46          Бузулук   не готов к переезду
#
#     Готовность к командировкам Гражданство Разрешение на работу  \
# 0        готов к командировкам      Россия               Россия
# 1        готов к командировкам      Россия               Россия
# 2        готов к командировкам    Беларусь               Россия
# ...
